# %% [markdown]
# <a href="https://colab.research.google.com/github/luizaraujo/Analise_de_Dados/blob/main/Dados_Agua_Rio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_dados = pd.read_csv('/content/_arquivos_Open_Data_Favorecidos_Covid19_2021.csv', encoding='1252')
display(df_dados)
# Out:
#       Órgão do empenho  ... Dir Ind
# 0                 1500  ...  DIRETA
# 1                 1500  ...  DIRETA
# 2                 1500  ...  DIRETA
# 3                 1500  ...  DIRETA
# 4                 1500  ...  DIRETA
# ...                ...  ...     ...
# 2171              3904  ...  DIRETA
# 2172              3904  ...  DIRETA
# 2173              3904  ...  DIRETA
# 2174              3904  ...  DIRETA
# 2175              3904  ...  DIRETA
#
# [2176 rows x 70 columns]

# %%
df_dados.head()
# Out:
#    Órgão do empenho  ... Dir Ind
# 0              1500  ...  DIRETA
# 1              1500  ...  DIRETA
# 2              1500  ...  DIRETA
# 3              1500  ...  DIRETA
# 4              1500  ...  DIRETA
#
# [5 rows x 70 columns]

# %%
df_dados.shape
# Out:
# (2176, 70)

# %%
df_dados.describe()
# Out:
#        Órgão do empenho  ...  Modalidade de aplicação
# count       2176.000000  ...                   2176.0
# mean        1887.980239  ...                     90.0
# std          339.802266  ...                      0.0
# min         1500.000000  ...                     90.0
# 25%         1824.000000  ...                     90.0
# 50%         1851.000000  ...                     90.0
# 75%         1875.000000  ...                     90.0
# max         3904.000000  ...                     90.0
#
# [8 rows x 23 columns]
