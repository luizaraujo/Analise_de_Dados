# %% [markdown]
# <a href="https://colab.research.google.com/github/luizaraujo/Analise_de_Dados/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_compras = pd.read_csv('/content/202108_ItemCompra.csv', encoding='windows-1252', sep=';')
display(df_compras)
# Out:
#    Código Órgão           Nome Órgão  ...  Quantidade Item  Valor Item
# 0         52131   Comando da Marinha  ...                1    10200,00
# 1         52121  Comando do Exército  ...              279  1674033,40
#
# [2 rows x 10 columns]

# %%
df_compras['Nome Órgão'].value_counts()
# Out:
# Comando do Exército    1
# Comando da Marinha     1
# Name: Nome Órgão, dtype: int64

# %%
df_educ = pd.read_excel('/content/913.xls')
display(df_educ)
# Out:
#                                              DATA.RIO Unnamed: 1 Unnamed: 2
# 0                                                 NaN        NaN        NaN
# 1   Tabela 913 - Ensino superior - Número e distri...        NaN        NaN
# 2                                                 NaN        NaN        NaN
# 3                                                 NaN        NaN        NaN
# 4                                            Capitais      Total          %
# 5                                                 NaN        NaN        NaN
# 6                                              Brasil      10585        100
# 7                                         12 Capitais       2920    27.5862
# 8                                           São Paulo        844    7.97355
# 9                                      Rio de Janeiro        556    5.25272
# 10                                           Curitiba        243     2.2957
# ...

# %%
df_educ['DATA.RIO'].value_counts()
# Out:
# Porto Alegre                                                                                                                                                                  1
# 12 Capitais                                                                                                                                                                   1
# Salvador                                                                                                                                                                      1
# Brasília                                                                                                                                                                      1
# Curitiba                                                                                                                                                                      1
# ...

# %%
df_agua = pd.read_excel('/content/2513.xls')
display(df_agua)

df_agua['Unnamed: 1'].value_counts()
# Out:
#                                      Data.Rio          ...                                 Unnamed: 7
# 0                                                 NaN  ...                                        NaN
# 1   Tabela 2513 - Indicadores de prestação do serv...  ...                                        NaN
# 2                                                 NaN  ...                                        NaN
# 3                                                 Ano  ...  Consumo médio mensal de água por economia
# 4                                                 NaN  ...                      (IN053) (m3/mês/econ)
# ..                                                ...  ...                                        ...
# 65                 considerado mesmo entre municíp...  ...                                        NaN
# 66                 produzido (AG006) do município ...  ...                                        NaN
# ...
